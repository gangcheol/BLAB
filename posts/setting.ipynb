# %% [raw]
# ---
# title: "기본 단축키 셋팅"
# author: "lgc"
# date: '06/02/26'
# ---

# %% [markdown]
# ## 주피터에 R단축키 추가하기

# %% [markdown]
# `1` Anaconda prompt에 다음과 같은 명령어를 입력하여 폴더 생성

# %% [markdown]
# ```Python
# mkdir "%USERPROFILE%\.jupyter\lab\user-settings\@jupyterlab\shortcuts-extension"
# ```

# %% [markdown]
# `2` 위 폴더에 단축키를 추가하고 적용할 `JSON`파일 생성

# %% [markdown]
# ```Python
# notepad "%USERPROFILE%\.jupyter\lab\user-settings\@jupyterlab\shortcuts-extension\shortcuts.jupyterlab-settings"
# ```

# %% [markdown]
# `3` 해당 경로를 타고, 파일을 연다음 아래 `노트`를 열어 코드를 복사 후, 본인이 자주쓰는 단축키(`%>%`, `<-`) 등을 추가.
#
# - 이후 주피터랩을 재실행하면 단축키가 적용됨

# %% [markdown]
# ::: {.callout-note collapse="true"}

# %% [markdown]
# ```python
# {
#   "shortcuts": [
#     {
#       "command": "apputils:run-first-enabled",
#       "selector": "body",
#       "keys": [
#         "Accel Shift M"
#       ],
#       "args": {
#         "commands": [
#           "console:replace-selection",
#           "fileeditor:replace-selection",
#           "notebook:replace-selection"
#         ],
#         "args": {
#           "text": " %>% "
#         }
#       }
#     },
#     {
#       "command": "apputils:run-first-enabled",
#       "selector": "body",
#       "keys": [
#         "Alt -"
#       ],
#       "args": {
#         "commands": [
#           "console:replace-selection",
#           "fileeditor:replace-selection",
#           "notebook:replace-selection"
#         ],
#         "args": {
#           "text": " <- "
#         }
#       }
#     }
#   ]
# }
# ```

# %% [markdown]
# :::
